# %%
exec(open("runner.py").read())
# Out:
# Converting PDF files to PNG files
# Converted PDF #1 to a PNG file
# Converted PDF #2 to a PNG file
# Converted PDF #3 to a PNG file
# Converted PDF #4 to a PNG file
# Converted PDF #5 to a PNG file
# TODO
# Cleaning old sliced files
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# Processing slice
# ...
